# %%
import pandas as pd

# %%
#Empty df
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
#From Lists to get Data 
city = ['Berlin','Dhaka','Delhi']
city
# Out:
# ['Berlin', 'Dhaka', 'Delhi']

# %%
df = pd.DataFrame(city)
df
# Out:
#         0
# 0  Berlin
# 1   Dhaka
# 2   Delhi

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(city)
# Out:
# list

# %%
row,col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df
# Out:
#         0
# 0  Berlin
# 1   Dhaka
# 2   Delhi

# %%
df = pd.DataFrame(city,columns=['City_in_World'])
df
# Out:
#   City_in_World
# 0        Berlin
# 1         Dhaka
# 2         Delhi

# %%
df = pd.DataFrame(city,columns=['City_in_World'],index=['Germany','Bangladesh','India'])
df
# Out:
#            City_in_World
# Germany           Berlin
# Bangladesh         Dhaka
# India              Delhi

# %%
city2 = ['Rangpur','Chittagong','Sylhet']
#Zipping 2 lists in one table
df2 = pd.DataFrame(zip(city,city2),columns=['City1','City2'])
df2
# Out:
#     City1       City2
# 0  Berlin     Rangpur
# 1   Dhaka  Chittagong
# 2   Delhi      Sylhet

# %%
df.shape
# Out:
# (3, 1)

# %%
df2.shape
# Out:
# (3, 2)

# %%
#Two Dimensional Lists
city3 = [['Bavaria','Erlangen'],['NRW','Dortmund']]

# %%
city3
# Out:
# [['Bavaria', 'Erlangen'], ['NRW', 'Dortmund']]

# %%
df4 = pd.DataFrame(city3,columns=['State','City'])

# %%
df4
# Out:
#      State      City
# 0  Bavaria  Erlangen
# 1      NRW  Dortmund

# %%
#Dictionary
dict1 = {
    'city1':city,
    'city2':city2
}

# %%
dict1
# Out:
# {'city1': ['Berlin', 'Dhaka', 'Delhi'],
#  'city2': ['Rangpur', 'Chittagong', 'Sylhet']}

# %%
df5= pd.DataFrame(dict1)

# %%
df5
# Out:
#     city1       city2
# 0  Berlin     Rangpur
# 1   Dhaka  Chittagong
# 2   Delhi      Sylhet

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dict1)
# Out:
# dict

# %%
#impoorting csv files
df = pd.read_csv('/mnt/c/Users/xtanv/Study Mart/Dataset/Screen Time Data.csv')

# %%
df
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
df.head() #will show first 5 row
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
df.tail() #will show last 5 row
# Out:
#           Date  Usage  Notifications  Times opened       App
# 49  09/17/2022    212            212           120  Whatsapp
# 50  09/18/2022    244            303           132  Whatsapp
# 51  09/19/2022     77            169           105  Whatsapp
# 52  09/20/2022     58            190            78  Whatsapp
# 53  09/21/2022     89            262            68  Whatsapp

# %%
df.head(10) # first 10
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instag
# 21             5
# 22             3
# 23             5
# 24             3
# 25             5
# 26             8
# 27           105
# 28            68
# 29            86
# 30            74
# 31            87
# 32            77
# 33            47
# 34           103
# 35            16
# 36            33
# 37           121
# 38           110
# 39            83
# 40            82
# 41           192
# 42            79
# 43            92
# 44           172
# 45            91
# 46            67
# 47            58
# 48            91
# 49           120
# 50           132
# ...

# %%
df[['Date','Times opened']]
# Out:
#           Date  Times opened
# 0   08/26/2022            49
# 1   08/27/2022            48
# 2   08/28/2022            55
# 3   08/29/2022            23
# 4   08/30/2022             5
# 5   08/31/2022            20
# 6   09/01/2022            57
# 7   09/02/2022            22
# 8   09/03/2022            25
# 9   09/04/2022            30
# 10  09/05/2022            51
# 11  09/06/2022            25
# 12  09/07/2022            19
# 13  09/08/2022            43
# 14  09/09/2022            70
# 15  09/10/2022            70
# 16  09/11/2022            95
# 17  09/12/2022           102
# 18  09/13/2022            39
# 19  09/14/2022             2
# 20  09/15/2022             4
# 21  09/16/2022             5
# 22  09/17/2022             3
# 23  09/18/2022             5
# 24  09/19/2022             3
# 25  09/20/2022             5
# 26  09/21/2022             8
# 27  08/26/2022           105
# 28  08/27/2022            68
# 29  08/28/2022            86
# 30  08/29/2022            74
# ...

# %%
df.head()
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
df['Notifications'].sort_values()
# Out:
# 23      8
# 24      8
# 22      9
# 19     10
# 25     11
# 26     12
# 21     13
# 8      15
# 20     15
# 4      19
# 6      23
# 12     23
# 10     24
# 5      25
# 7      28
# 9      29
# 11     34
# 3      35
# 36     38
# 1      43
# 18     45
# 13     48
# 14     68
# 0      70
# 15     71
# 35     80
# 17     99
# 33     99
# 28    111
# 34    144
# 45    153
# 30    157
# 42    166
# 32    169
# 51    169
# 43    173
# 48    176
# 16    180
# 47    181
# 29    183
# 52    190
# 46    192
# 38    205
# 27    209
# 39    212
# 49    212
# 40    217
# 37    218
# 2     231
# 31    246
# 53    262
# 44    290
# 50    303
# 41    405
# Name: Notifications, dtype: int64

# %%
df['Notifications'].sort_values(ascending=False)
# Out:
# 41    405
# 50    303
# 44    290
# 53    262
# 31    246
# 2     231
# 37    218
# 40    217
# 49    212
# 39    212
# 27    209
# 38    205
# 46    192
# 52    190
# 29    183
# 47    181
# 16    180
# 48    176
# 43    173
# 51    169
# 32    169
# 42    166
# 30    157
# 45    153
# 34    144
# 28    111
# 17     99
# 33     99
# 35     80
# 15     71
# 0      70
# 14     68
# 13     48
# 18     45
# 1      43
# 36     38
# 3      35
# 11     34
# 9      29
# 7      28
# 5      25
# 10     24
# 12     23
# 6      23
# 4      19
# 20     15
# 8      15
# 21     13
# 26     12
# 25     11
# 19     10
# 22      9
# 24      8
# 23      8
# Name: Notifications, dtype: int64

# %%
df.sort_values('Notifications',ascending=False)
# Out:
#           Date  Usage  Notifications  Times opened        App
# 41  09/09/2022    119            405           192   Whatsapp
# 50  09/18/2022    244            303           132   Whatsapp
# 44  09/12/2022    182            290           172   Whatsapp
# 53  09/21/2022     89            262            68   Whatsapp
# 31  08/30/2022    128            246            87   Whatsapp
# 2   08/28/2022     64            231            55  Instagram
# 37  09/05/2022    126            218           121   Whatsapp
# 40  09/08/2022     69            217            82   Whatsapp
# 49  09/17/2022    212            212           120   Whatsapp
# 39  09/07/2022    160            212            83   Whatsapp
# 27  08/26/2022     82            209           105   Whatsapp
# 38  09/06/2022     91            205           110   Whatsapp
# 46  09/14/2022     64            192            67   Whatsapp
# 52  09/20/2022     58            190            78   Whatsapp
# ...

# %%
df.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %%
df[df['Times opened']>100]
# Out:
#           Date  Usage  Notifications  Times opened        App
# 17  09/12/2022    114             99           102  Instagram
# 27  08/26/2022     82            209           105   Whatsapp
# 34  09/02/2022     76            144           103   Whatsapp
# 37  09/05/2022    126            218           121   Whatsapp
# 38  09/06/2022     91            205           110   Whatsapp
# 41  09/09/2022    119            405           192   Whatsapp
# 44  09/12/2022    182            290           172   Whatsapp
# 49  09/17/2022    212            212           120   Whatsapp
# 50  09/18/2022    244            303           132   Whatsapp
# 51  09/19/2022     77            169           105   Whatsapp

# %%
df[df['App']=='Instagram']
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
df[(df['App']=='Instagram') | (df['App']=='Whatsapp')  ]
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
df['App'].isin(['Instagram','Whatsapp'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# Name: App, dtype: bool

# %%
df[df['App'].isin(['Instagram','Whatsapp'])]
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
df.head()
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
conda install gspread
# Out:
# 3357.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Channels:
#  - conda-forge
#  - rapidsai
# Platform: linux-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
